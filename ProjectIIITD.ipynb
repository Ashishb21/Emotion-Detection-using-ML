# %%
import sys, os
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
BASEPATH = './drive/My Drive/Emotion Recognition/'
sys.path.insert(0, BASEPATH)
os.chdir(BASEPATH)
MODELPATH = './drive/My Drive/Emotion Recognition/model.hdf5'

# %%
data = pd.read_csv('./fer2013.csv')
data.shape
# Out:
# (35887, 3)

# %%
num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48

# %%
pixels = data['pixels'].tolist() # 1

faces = []
for pixel_sequence in pixels:
    face = [int(pixel) for pixel in pixel_sequence.split(' ')] # 2
    face = np.asarray(face).reshape(width, height) # 3
    
    # There is an issue for normalizing images. Just comment out 4 and 5 lines until when I found the solution.
    # face = face / 255.0 # 4
    # face = cv2.resize(face.astype('uint8'), (width, height)) # 5
    faces.append(face.astype('float32'))

faces = np.asarray(faces)
faces = np.expand_dims(faces, -1) # 6

emotions = pd.get_dummies(data['emotion']).as_matrix() # 7

# %%
X_train, X_test, y_train, y_test = train_test_split(faces, emotions, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=41)

# %%
model = Sequential()

model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 5,905,863
# Trainable params: 5,902,151
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])

# %%
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, verbose=1)

# %%
tensorboard = TensorBoard(log_dir='./logs')

# %%
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto')

# %%
checkpointer = ModelCheckpoint(MODELPATH, monitor='val_loss', verbose=1, save_best_only=True)

# %%
model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_test), np.array(y_test)),
          shuffle=True,
          callbacks=[lr_reducer, tensorboard, early_stopper, checkpointer])
# Out:
# Train on 29068 samples, validate on 3589 samples
# Epoch 1/100
# 29068/29068 [==============================] - 62s 2ms/step - loss: 1.9996 - acc: 0.2144 - val_loss: 1.8175 - val_acc: 0.2449
#
# Epoch 00001: val_loss improved from inf to 1.81749, saving model to ./model.hdf5
# Epoch 2/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.8354 - acc: 0.2471 - val_loss: 1.8759 - val_acc: 0.2455
#
# Epoch 00002: val_loss did not improve from 1.81749
# Epoch 3/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.8016 - acc: 0.2633 - val_loss: 1.8799 - val_acc: 0.2455
#
# Epoch 00003: val_loss did not improve from 1.81749
# Epoch 4/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.7286 - acc: 0.3055 - val_loss: 1.6035 - val_acc: 0.3508
#
# Epoch 00004: val_loss improved from 1.81749 to 1.60349, saving model to ./model.hdf5
# Epoch 5/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.6230 - acc: 0.3557 - val_loss: 1.5996 - val_acc: 0.3346
#
# Epoch 00005: val_loss improved from 1.60349 to 1.59962, saving model to ./model.hdf5
# Epoch 6/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.5300 - acc: 0.3952 - val_loss: 1.4910 - val_acc: 0.3990
#
# Epoch 00006: val_loss improved from 1.59962 to 1.49105, saving model to ./model.hdf5
# Epoch 7/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.4719 - acc: 0.4192 - val_loss: 1.4209 - val_acc: 0.4310
#
# Epoch 00007: val_loss improved from 1.49105 to 1.42089, saving model to ./model.hdf5
# Epoch 8/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.4327 - acc: 0.4455 - val_loss: 1.3752 - val_acc: 0.4614
#
# Epoch 00008: val_loss improved from 1.42089 to 1.37524, saving model to ./model.hdf5
# Epoch 9/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.3953 - acc: 0.4690 - val_loss: 1.2982 - val_acc: 0.5121
#
# Epoch 00009: val_loss improved from 1.37524 to 1.29824, saving model to ./model.hdf5
# Epoch 10/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.3550 - acc: 0.4841 - val_loss: 1.3759 - val_acc: 0.4848
#
# Epoch 00010: val_loss did not improve from 1.29824
# Epoch 11/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.3166 - acc: 0.4964 - val_loss: 1.2733 - val_acc: 0.5283
#
# Epoch 00011: val_loss improved from 1.29824 to 1.27333, saving model to ./model.hdf5
# Epoch 12/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.2870 - acc: 0.5192 - val_loss: 1.2273 - val_acc: 0.5464
#
# Epoch 00012: val_loss improved from 1.27333 to 1.22734, saving model to ./model.hdf5
# Epoch 13/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.2560 - acc: 0.5325 - val_loss: 1.2752 - val_acc: 0.5219
#
# Epoch 00013: val_loss did not improve from 1.22734
# Epoch 14/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.2310 - acc: 0.5414 - val_loss: 1.2541 - val_acc: 0.5313
#
# Epoch 00014: val_loss did not improve from 1.22734
# Epoch 15/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.2102 - acc: 0.5545 - val_loss: 1.1792 - val_acc: 0.5587
#
# Epoch 00015: val_loss improved from 1.22734 to 1.17917, saving model to ./model.hdf5
# Epoch 16/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.1893 - acc: 0.5602 - val_loss: 1.1883 - val_acc: 0.5639
#
# Epoch 00016: val_loss did not improve from 1.17917
# Epoch 17/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.1655 - acc: 0.5747 - val_loss: 1.1070 - val_acc: 0.5885
#
# Epoch 00017: val_loss improved from 1.17917 to 1.10703, saving model to ./model.hdf5
# Epoch 18/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.1358 - acc: 0.5814 - val_loss: 1.1146 - val_acc: 0.5860
#
# Epoch 00018: val_loss did not improve from 1.10703
# Epoch 19/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.1194 - acc: 0.5900 - val_loss: 1.1392 - val_acc: 0.5754
#
# Epoch 00019: val_loss did not improve from 1.10703
# Epoch 20/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.0970 - acc: 0.5989 - val_loss: 1.1210 - val_acc: 0.5882
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00020: val_loss did not improve from 1.10703
# Epoch 21/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.0629 - acc: 0.6110 - val_loss: 1.1168 - val_acc: 0.5854
#
# Epoch 00021: val_loss did not improve from 1.10703
# Epoch 22/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.0412 - acc: 0.6200 - val_loss: 1.1055 - val_acc: 0.5977
#
# Epoch 00022: val_loss improved from 1.10703 to 1.10554, saving model to ./model.hdf5
# Epoch 23/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 1.0283 - acc: 0.6270 - val_loss: 1.0748 - val_acc: 0.6147
#
# Epoch 00023: val_loss improved from 1.10554 to 1.07477, saving model to ./model.hdf5
# Epoch 24/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9941 - acc: 0.6372 - val_loss: 1.0706 - val_acc: 0.6102
#
# Epoch 00024: val_loss improved from 1.07477 to 1.07060, saving model to ./model.hdf5
# Epoch 25/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9779 - acc: 0.6419 - val_loss: 1.0732 - val_acc: 0.6119
#
# Epoch 00025: val_loss did not improve from 1.07060
# Epoch 26/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9552 - acc: 0.6521 - val_loss: 1.1207 - val_acc: 0.5832
#
# Epoch 00026: val_loss did not improve from 1.07060
# Epoch 27/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9372 - acc: 0.6610 - val_loss: 1.0579 - val_acc: 0.6199
#
# Epoch 00027: val_loss improved from 1.07060 to 1.05793, saving model to ./model.hdf5
# Epoch 28/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9231 - acc: 0.6660 - val_loss: 1.0843 - val_acc: 0.6227
#
# Epoch 00028: val_loss did not improve from 1.05793
# Epoch 29/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.9048 - acc: 0.6728 - val_loss: 1.0445 - val_acc: 0.6205
#
# Epoch 00029: val_loss improved from 1.05793 to 1.04452, saving model to ./model.hdf5
# Epoch 30/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.8957 - acc: 0.6753 - val_loss: 1.0594 - val_acc: 0.6119
#
# Epoch 00030: val_loss did not improve from 1.04452
# Epoch 31/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.8640 - acc: 0.6886 - val_loss: 1.0828 - val_acc: 0.6197
#
# Epoch 00031: val_loss did not improve from 1.04452
# Epoch 32/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.8590 - acc: 0.6897 - val_loss: 1.0920 - val_acc: 0.6183
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00032: val_loss did not improve from 1.04452
# Epoch 33/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.8210 - acc: 0.7025 - val_loss: 1.0615 - val_acc: 0.6330
#
# Epoch 00033: val_loss did not improve from 1.04452
# Epoch 34/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.8059 - acc: 0.7081 - val_loss: 1.0665 - val_acc: 0.6353
#
# Epoch 00034: val_loss did not improve from 1.04452
# Epoch 35/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.7969 - acc: 0.7134 - val_loss: 1.0725 - val_acc: 0.6389
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00035: val_loss did not improve from 1.04452
# Epoch 36/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.7623 - acc: 0.7233 - val_loss: 1.0682 - val_acc: 0.6311
#
# Epoch 00036: val_loss did not improve from 1.04452
# Epoch 37/100
# 29068/29068 [==============================] - 57s 2ms/step - loss: 0.7375 - acc: 0.7379 - val_loss: 1.0740 - val_acc: 0.6358
#
# Epoch 00037: val_loss did not improve from 1.04452
# Epoch 00037: early stopping

# %%
scores = model.evaluate(np.array(X_test), np.array(y_test), batch_size=batch_size)
print("Loss: " + str(scores[0]))
print("Accuracy: " + str(scores[1]))
# Out:
# 3589/3589 [==============================] - 2s 552us/step
# Loss: 1.0740430999612636
# Accuracy: 0.635831708013264

# %%
ls -ll
# Out:
# total 69332
# drwx------ 3 root root     4096 Nov 29 05:03 drive/
# drwxr-xr-x 2 root root     4096 Nov 29 05:11 logs/
# -rw-r--r-- 1 root root 70982096 Nov 29 05:39 model.hdf5
# drwxr-xr-x 2 root root     4096 Nov 21 17:36 sample_data/

# %%
ls -ll
# Out:
# total 4
# drwxr-xr-x 2 root root 4096 Nov 29 18:21 sample_data/

# %%
pwd
# Out:
# '/content'
